# %% [markdown]
# # Ectracting the List of postal codes of Canada: M using web scrapping
# This notebook contains the code to scrap the list of postal codes of canada and convert it into a dataframe.

# %% [markdown]
# #### Importing the required libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# #### Setting the url to the given wikipedia page which contains the list. then making the rwquest to get the data

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
s = requests.get(url)

# %% [markdown]
# #### Reading the dataframe from the data then refining the dataframe to get the required table.

# %%
data_frame = pd.read_html(url)[0].dropna().sort_values(by = 'Postal Code').reset_index().drop(columns = ['index'])

# %% [markdown]
# #### Shape of the dataframe and the dataframe is printed below.

# %%
# data_frame.sort_values(by = 'Postal Code', inplace = True)

# %%
data_frame
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# ...

# %%
# import geocoder # import geocoder

# %%
# postal_codes = list(data_frame['Postal Code'])

# %%
# Out:
# ['M3A',
#  'M4A',
#  'M5A',
#  'M6A',
#  'M7A',
#  'M9A',
#  'M1B',
#  'M3B',
#  'M4B',
#  'M5B',
#  'M6B',
#  'M9B',
#  'M1C',
#  'M3C',
#  'M4C',
#  'M5C',
#  'M6C',
#  'M9C',
#  'M1E',
#  'M4E',
#  'M5E',
#  'M6E',
#  'M1G',
#  'M4G',
#  'M5G',
#  'M6G',
#  'M1H',
#  'M2H',
#  'M3H',
#  'M4H',
#  'M5H',
#  'M6H',
#  'M1J',
#  'M2J',
#  'M3J',
#  'M4J',
#  'M5J',
#  'M6J',
#  'M1K',
#  'M2K',
#  'M3K',
#  'M4K',
#  'M5K',
#  'M6K',
#  'M1L',
#  'M2L',
#  'M3L',
#  'M4L',
#  'M5L',
#  'M6L',
#  'M9L',
#  'M1M',
#  'M2M',
#  'M3M',
#  'M4M',
#  'M5M',
#  'M6M',
#  'M9M',
#  'M1N',
#  'M2N',
#  'M3N',
#  'M4N',
#  'M5N',
#  'M6N',
#  'M9N',
#  'M1P',
#  'M2P',
#  'M4P',
#  'M5P',
#  'M6P',
#  'M9P',
#  'M1R',
#  'M2R',
#  'M4R',
#  'M5R',
#  'M6R',
#  'M7R',
#  'M9R',
#  'M1S',
#  'M4S',
#  'M5S',
#  'M6S',
#  'M1T',
#  'M4T',
#  'M5T',
#  'M1V',
#  'M4V',
#  'M5V',
#  'M8V',
#  'M9V',
#  'M1W',
#  'M4W',
#  'M5W',
#  'M8W',
#  'M9W',
#  'M1X',
#  'M4X',
#  'M5X',
#  'M8X',
#  'M4Y',
# ...

# %%
# Long_lat = []
# for post in postal_codes:
#     lat_lng_coords = None

#     # loop until you get the coordinates
#     while(lat_lng_coords is None):
#         g = geocoder.google('{}'.format(post))
#         lat_lng_coords = g.latlng

#     latitude = lat_lng_coords[0]
#     longitude = lat_lng_coords[1]
#     Long_lat.append([latitude, longitude])

# %%
postal_ll = pd.read_csv('Geospatial_Coordinates.csv')

# %%
postal_ll.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
data_frame['latitude'] = postal_ll['Latitude']
data_frame['longitude'] = postal_ll['Longitude']

# %%
data_frame
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# ...
